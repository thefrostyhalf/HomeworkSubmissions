# %% [markdown]
# # Python APIs
# ## Jackie McGuire
#
# This code uses the Open Weather Map API to retrieve a user-defined number of cities and create scatterplots for Temperature, Humidity, Cloudiness and Windiness.
#
# Note: There is a 1-second wait built in between cit

# %%
# Dependencies
import matplotlib.pyplot as plt
import requests as req
import pandas as pd
import sys 
import os 
import apikeys
from citipy import citipy
import random
import time
import datetime
now = datetime.datetime.now()

# %%
url = "http://api.openweathermap.org/data/2.5/weather"

params = {'appid': apikeys.OMW_API_KEY,
          'q': '',
          'units': 'metric'}

weather_data = []
coords=[]
cities = set()
dataset_number = input("How many random cities (@60 cities per minute) would you like to get data for?")
apireq = 1
idx=1
while len(weather_data)<int(dataset_number):
    oldcitieslen = len(cities)
    newcitieslen = len(cities)
    while newcitieslen==oldcitieslen:
        city = citipy.nearest_city((random.randint(-9000,9000)/100),(random.randint(-18000,18000)/100))
        city_name = city.city_name
        country_code = city.country_code
        newcity=(city_name+","+country_code.upper())
        cities.add(newcity)
        newcitieslen = len(cities)
    params['q'] = newcity
    response=req.get(url, params=params)
    response_json = response.json()
    if response_json["cod"]==200:
        weather_data.append(response.json())
        print("API Request ",apireq, ", City Number", idx , ", Weather Data For ", newcity,"\n", response.url, "...Successful")
        apireq=apireq+1
        idx=idx+1
        time.sleep(1)   
    else:
        print("API Request ", apireq , " Weather Data For ", newcity,"\n", response.url, "...ERROR:", response_json["cod"], response_json["message"],"CITY NOT ADDED TO DATA")
        apireq=apireq+1
        time.sleep(1)
# Out:
# How many random cities (@60 cities per minute) would you like to get data for?50
# API Request  1 , City Number 1 , Weather Data For  bredasdorp,ZA
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=bredasdorp%2CZA&units=metric ...Successful
# API Request  2 , City Number 2 , Weather Data For  mar del plata,AR
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=mar+del+plata%2CAR&units=metric ...Successful
# API Request  3 , City Number 3 , Weather Data For  plettenberg bay,ZA
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=plettenberg+bay%2CZA&units=metric ...Successful
# API Request  4 , City Number 4 , Weather Data For  shimoda,JP
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=shimoda%2CJP&units=metric ...Successful
# API Request  5 , City Number 5 , Weather Data For  ovalle,CL
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=ovalle%2CCL&units=metric ...Successful
# API Request  6 , City Number 6 , Weather Data For  komsomolskiy,RU
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=komsomolskiy%2CRU&units=metric ...Successful
# API Request  7 , City Number 7 , Weather Data For  wenling,CN
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=wenling%2CCN&units=metric ...Successful
# API Request  8 , City Number 8 , Weather Data For  arraial do cabo,BR
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=arraial+do+cabo%2CBR&units=metric ...Successful
# API Request  9 , City Number 9 , Weather Data For  sioux lookout,CA
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=sioux+lookout%2CCA&units=metric ...Successful
# API Request  10 , City Number 10 , Weather Data For  punta arenas,CL
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=punta+arenas%2CCL&units=metric ...Successful
# API Request  11 , City Number 11 , Weather Data For  xifeng,CN
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=xifeng%2CCN&units=metric ...Successful
# API Request  12 , City Number 12 , Weather Data For  avarua,CK
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=avarua%2CCK&units=metric ...Successful
# API Request  13 , City Number 13 , Weather Data For  ushuaia,AR
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=ushuaia%2CAR&units=metric ...Successful
# API Request  14  Weather Data For  kaitangata,NZ
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=kaitangata%2CNZ&units=metric ...ERROR: 404 city not found CITY NOT ADDED TO DATA
# API Request  15 , City Number 14 , Weather Data For  hermanus,ZA
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=hermanus%2CZA&units=metric ...Successful
# API Request  16 , City Number 15 , Weather Data For  krasnovishersk,RU
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=krasnovishersk%2CRU&units=metric ...Successful
# API Request  17 , City Number 16 , Weather Data For  rikitea,PF
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=rikitea%2CPF&units=metric ...Successful
# API Request  18 , City Number 17 , Weather Data For  cap malheureux,MU
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=cap+malheureux%2CMU&units=metric ...Successful
# API Request  19 , City Number 18 , Weather Data For  inhambane,MZ
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=inhambane%2CMZ&units=metric ...Successful
# API Request  20 , City Number 19 , Weather Data For  naze,JP
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=naze%2CJP&units=metric ...Successful
# API Request  21 , City Number 20 , Weather Data For  pedra azul,BR
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=pedra+azul%2CBR&units=metric ...Successful
# API Request  22 , City Number 21 , Weather Data For  georgetown,SH
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=georgetown%2CSH&units=metric ...Successful
# API Request  23 , City Number 22 , Weather Data For  talant,FR
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=talant%2CFR&units=metric ...Successful
# API Request  24  Weather Data For  henties bay,NA
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=henties+bay%2CNA&units=metric ...ERROR: 404 city not found CITY NOT ADDED TO DATA
# API Request  25 , City Number 23 , Weather Data For  maceio,BR
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=maceio%2CBR&units=metric ...Successful
# API Request  26 , City Number 24 , Weather Data For  bethel,US
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=bethel%2CUS&units=metric ...Successful
# API Request  27 , City Number 25 , Weather Data For  shache,CN
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=shache%2CCN&units=metric ...Successful
# API Request  28 , City Number 26 , Weather Data For  chokurdakh,RU
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=chokurdakh%2CRU&units=metric ...Successful
# API Request  29  Weather Data For  karkaralinsk,KZ
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=karkaralinsk%2CKZ&units=metric ...ERROR: 404 city not found CITY NOT ADDED TO DATA
# API Request  30 , City Number 27 , Weather Data For  amahai,ID
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=amahai%2CID&units=metric ...Successful
# API Request  31 , City Number 28 , Weather Data For  thompson,CA
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=thompson%2CCA&units=metric ...Successful
# API Request  32 , City Number 29 , Weather Data For  omsukchan,RU
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=omsukchan%2CRU&units=metric ...Successful
# API Request  33 , City Number 30 , Weather Data For  kruisfontein,ZA
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=kruisfontein%2CZA&units=metric ...Successful
# API Request  34 , City Number 31 , Weather Data For  east london,ZA
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=east+london%2CZA&units=metric ...Successful
# API Request  35 , City Number 32 , Weather Data For  stornoway,GB
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=stornoway%2CGB&units=metric ...Successful
# API Request  36 , City Number 33 , Weather Data For  saldanha,ZA
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=saldanha%2CZA&units=metric ...Successful
# API Request  37 , City Number 34 , Weather Data For  jamestown,SH
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=jamestown%2CSH&units=metric ...Successful
# API Request  38 , City Number 35 , Weather Data For  mbaiki,CF
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=mbaiki%2CCF&units=metric ...Successful
# API Request  39 , City Number 36 , Weather Data For  vaini,TO
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=vaini%2CTO&units=metric ...Successful
# API Request  40  Weather Data For  labutta,MM
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=labutta%2CMM&units=metric ...ERROR: 404 city not found CITY NOT ADDED TO DATA
# API Request  41 , City Number 37 , Weather Data For  new norfolk,AU
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=new+norfolk%2CAU&units=metric ...Successful
# API Request  42 , City Number 38 , Weather Data For  yen bai,VN
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=yen+bai%2CVN&units=metric ...Successful
# API Request  43  Weather Data For  kapoeta,SD
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=kapoeta%2CSD&units=metric ...ERROR: 404 city not found CITY NOT ADDED TO DATA
# API Request  44 , City Number 39 , Weather Data For  katsuura,JP
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=katsuura%2CJP&units=metric ...Successful
# API Request  45 , City Number 40 , Weather Data For  longyearbyen,SJ
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=longyearbyen%2CSJ&units=metric ...Successful
# API Request  46 , City Number 41 , Weather Data For  castro,CL
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=castro%2CCL&units=metric ...Successful
# API Request  47 , City Number 42 , Weather Data For  tasiilaq,GL
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=tasiilaq%2CGL&units=metric ...Successful
# API Request  48 , City Number 43 , Weather Data For  jinan,CN
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=jinan%2CCN&units=metric ...Successful
# API Request  49  Weather Data For  mataura,PF
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=mataura%2CPF&units=metric ...ERROR: 404 city not found CITY NOT ADDED TO DATA
# API Request  50 , City Number 44 , Weather Data For  aykhal,RU
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=aykhal%2CRU&units=metric ...Successful
# API Request  51 , City Number 45 , Weather Data For  cape town,ZA
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=cape+town%2CZA&units=metric ...Successful
# API Request  52 , City Number 46 , Weather Data For  albany,AU
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=albany%2CAU&units=metric ...Successful
# API Request  53 , City Number 47 , Weather Data For  balsta,SE
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=balsta%2CSE&units=metric ...Successful
# API Request  54 , City Number 48 , Weather Data For  tiksi,RU
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=tiksi%2CRU&units=metric ...Successful
# API Request  55 , City Number 49 , Weather Data For  qaanaaq,GL
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=qaanaaq%2CGL&units=metric ...Successful
# API Request  56  Weather Data For  seddon,NZ
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=seddon%2CNZ&units=metric ...ERROR: 404 city not found CITY NOT ADDED TO DATA
# API Request  57 , City Number 50 , Weather Data For  biltine,TD
#  http://api.openweathermap.org/data/2.5/weather?appid=4dbb73a13873cd025cdc7281bc5c34e8&q=biltine%2CTD&units=metric ...Successful

# %%
        
# Create lists of latitudes and temperatures
name_data=[]
lat_data = []
temp_data = []
humid_data=[]
cloud_data=[]
wind_data=[]
weather_dict = {"City Name": name_data,
                            "Temperature": temp_data, 
                            "Latitude": lat_data, 
                           "Humidity":humid_data,
                           "Cloudiness": cloud_data,
                           "Windiness": wind_data}

# %%
for data in weather_data:
        name_data.append(data["name"])
        lat_data.append(data['coord']['lat'])
        temp_data.append(data['main']['temp'])
        humid_data.append(data['main']['humidity'])
        cloud_data.append(data["clouds"]["all"])
        wind_data.append(data["wind"]["speed"])

# %%
weather_data_df = pd.DataFrame(weather_dict)

# %%
def latitude_graph(variable):
    weather_data_df.plot.scatter(x='Latitude', y=variable, c=variable, cmap='seismic', figsize=(10,10))
    plt.title(variable+" by Latitude "+(now.strftime("%Y-%m-%d %H:%M")))
    plt.xlabel("Latitude of Cities")
    plt.ylabel("Current "+variable)
    plt.grid()
    plt.show()
    plt.savefig(variable+"byLatitude")

temp_lat_graph = latitude_graph("Temperature")

# %%
humid_lat_graph =latitude_graph("Humidity")

# %%
cloud_lat_graph = latitude_graph("Cloudiness")

# %%
wind_lat_graph = latitude_graph("Windiness")
