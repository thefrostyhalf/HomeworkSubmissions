# %%
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
import pandas as pd
import datetime as d
import matplotlib.pyplot as plt
import numpy as np

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
Base = automap_base()

# %%
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
Measurement = Base.classes.measurement

# %%
Station = Base.classes.station

# %%
session = Session(engine)

# %%
list(Measurement.__table__.columns)
# Out:
# [Column('meas_id', INTEGER(), table=<measurement>, primary_key=True, nullable=False),
#  Column('station', VARCHAR(), table=<measurement>),
#  Column('date', VARCHAR(), table=<measurement>),
#  Column('prcp', INTEGER(), table=<measurement>),
#  Column('tobs', INTEGER(), table=<measurement>)]

# %%
list(Station.__table__.columns)
# Out:
# [Column('station_id', INTEGER(), table=<station>, primary_key=True, nullable=False),
#  Column('station', VARCHAR(), table=<station>),
#  Column('name', VARCHAR(), table=<station>),
#  Column('latitude', INTEGER(), table=<station>),
#  Column('longitude', INTEGER(), table=<station>),
#  Column('elevation', INTEGER(), table=<station>)]

# %%
results = (session
         .query(Measurement.date, Measurement.prcp)
         .all())

for row in query:
    print(row)
# Out:
# ('2010-01-01', 0.08)
# ('2010-01-02', 0)
# ('2010-01-03', 0)
# ('2010-01-04', 0)
# ('2010-01-07', 0.06)
# ('2010-01-08', 0)
# ('2010-01-09', 0)
# ('2010-01-10', 0)
# ('2010-01-11', 0.01)
# ('2010-01-12', 0)
# ('2010-01-14', 0)
# ('2010-01-15', 0)
# ('2010-01-16', 0)
# ('2010-01-17', 0)
# ('2010-01-18', 0)
# ('2010-01-19', 0)
# ('2010-01-20', 0)
# ('2010-01-21', 0)
# ('2010-01-22', 0)
# ('2010-01-23', 0)
# ('2010-01-24', 0.01)
# ('2010-01-25', 0)
# ('2010-01-26', 0.04)
# ('2010-01-27', 0.12)
# ('2010-01-28', 0)
# ('2010-01-31', 0.03)
# ('2010-02-01', 0.01)
# ('2010-02-04', 0.01)
# ('2010-02-05', 0)
# ('2010-02-06', 0)
# ('2010-02-07', 0)
# ('2010-02-08', 0)
# ('2010-02-09', 0)
# ('2010-02-11', 0)
# ('2010-02-12', 0.02)
# ('2010-02-13', 0.01)
# ('2010-02-14', 0)
# ('2010-02-15', 0)
# ('2010-02-16', 0)
# ('2010-02-17', 0)
# ('2010-02-20', 0.03)
# ('2010-02-21', 0)
# ('2010-02-22', 0)
# ('2010-02-23', 0)
# ('2010-02-24', 0)
# ('2010-02-25', 0)
# ('2010-02-26', 0)
# ('2010-02-28', 0)
# ...

# %%
date_id = [result[0] for result in results]
percip = [int(result[1]) for result in results]

# %%
prcp_df = pd.DataFrame(list(results))
prcp_df['date'] = pd.to_datetime(prcp_df['date'])

# %%
oneyr_df = prcp_df.loc[(prcp_df['date'] > (d.datetime.now() - d.timedelta(days=365)))]
plt.figure()
oneyr_chart = oneyr_df.plot(kind='bar',title='Percipitation in Hawaii (Previous 12mo)', xticks=(np.arange(12)))
plt.show()
